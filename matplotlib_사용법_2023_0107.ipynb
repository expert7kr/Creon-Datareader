# %% [markdown]
# <a href="https://colab.research.google.com/github/expert7kr/Creon-Datareader/blob/master/matplotlib_%EC%82%AC%EC%9A%A9%EB%B2%95_2023_0107.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### 플롯차트

# %%
from matplotlib import pyplot as plt

plt.plot([1,2,3], [50, 100, 85])
plt.show()

# %%
from matplotlib import pyplot as plt

plt.plot([1,2,3], [50, 100, 85])
plt.xlabel('x label testing')
plt.ylabel('y label testing')
plt.title('plot testing')
plt.show()

# %%
from matplotlib import pyplot as plt

plt.plot([1,2,3], [50, 100, 85])
plt.plot([2,3,4], [30, 70, 95])
plt.xlabel('x label testing')
plt.ylabel('y label testing')
plt.title('plot testing')
plt.legend(['leg1', 'leg2'])
plt.show()

# %% [markdown]
# #### 바차트

# %%
from matplotlib import pyplot as plt
# import matplotlib.pyplot as plt

plt.bar([1,2,3], [50, 100, 85], width=0.8, color="red")
# plt.plot([2,3,4], [30, 70, 95])
plt.xlabel('x label testing')
plt.ylabel('y label testing')
plt.title('plot testing')
# plt.legend(['leg1', 'leg2'])
plt.show()

# %% [markdown]
# #### matplotlib API > examples
# https://matplotlib.org/stable/gallery/index.html

# %% [markdown]
# 0:36 / 25:28
#
#
# #### [python] 주식 데이터 가져오기와 차트 그리기_1편. 소스코드 설명
# https://www.youtube.com/watch?v=ArUEyhVm-y0

# %%
import pandas as pd

stock_code = pd.read_html('http://kind.krx.co.kr/corpgeneral/corpList.do?method=download', header=0)[0]

# %%
stock_code.sort_values(['상장일'], ascending=True)
# Out:
#            회사명    종목코드                   업종  \
# 1036  한진중공업홀딩스    3480    연료용 가스 제조 및 배관공급업
# 2269     유수홀딩스     700  회사 본부 및 경영 컨설팅 서비스업
# 1603        경방      50               종합 소매업
# 36       메리츠화재      60                  보험업
# 934     CJ대한통운     120            도로 화물 운송업
# ...        ...     ...                  ...
# 819        신스틸  162300            1차 철강 제조업
# 1125    신영스팩9호  445970           금융 지원 서비스업
# 1260       타이드  346010             전자부품 제조업
# 1878    아이오바이오  447690           의료용 기기 제조업
# 549       옵티코어  380540     마그네틱 및 광학 매체 제조업
#
#                                                    주요제품         상장일  결산월  \
# 1036                                               지주회사  1956-03-03  12월
# 2269                                               지주사업  1956-03-03  12월
# 1603          섬유류(면사,면혼방사,면직물,면혼방직물,화섬사,화섬직물) 제조,도매,수출입  1956-03-03  12월
# 36                                     손해보험(화재,해상,운송보험)  1956-07-02  12월
# ...

# %%
stock_code = stock_code[['회사명', '종목코드']]
stock_code
# Out:
#             회사명    종목코드
# 0         DRB동일    4840
# 1           DSR  155660
# 2            GS   78930
# 3     HDC현대산업개발  294870
# 4         KG케미칼    1390
# ...         ...     ...
# 2564     카이바이오텍  446600
# 2565     코스텍시스템  169670
# 2566       타임기술  318660
# 2567   플럼라인생명과학  222670
# 2568   한국미라클피플사  331660
#
# [2569 rows x 2 columns]

# %%
stock_code = stock_code.rename(columns={'회사명': 'company', '종목코드': 'code'})
stock_code.head(10) # 상위 5개행
# stock_code.info()
# Out:
#      company    code
# 0      DRB동일  004840
# 1        DSR  155660
# 2         GS  078930
# 3  HDC현대산업개발  294870
# 4      KG케미칼  001390
# 5     KPX케미칼  025000
# 6      KSS해운  044450
# 7       KTis  058860
# 8      LG이노텍  011070
# 9     LG헬로비전  037560

# %% [markdown]
# ##### 참고

# %%
stock_code.describe()
# Out:
#                 code
# count    2569.000000
# mean   135604.371351
# std    142906.121824
# min        20.000000
# 25%     28080.000000
# 50%     84440.000000
# 75%    222160.000000
# max    950220.000000

# %%
# stock_code['company'].unique()
stock_code['company'].nunique()
# Out:
# 2569

# %%
# stock_code.head(10)
stock_code.tail(10)
# Out:
#        company    code
# 2559    에이펙스인텍  207490
# 2560       원포유  122830
# 2561       위월드  140660
# 2562       이엠티  232530
# 2563   지앤이헬스케어  299480
# 2564    카이바이오텍  446600
# 2565    코스텍시스템  169670
# 2566      타임기술  318660
# 2567  플럼라인생명과학  222670
# 2568  한국미라클피플사  331660

# %% [markdown]
# #### 계속

# %%
# stock_code.code = stock_code.code.map('{:06d}'.format) # 코드를 6자리로 맞추기 위해서
stock_code
# Out:
#         company    code
# 0         DRB동일  004840
# 1           DSR  155660
# 2            GS  078930
# 3     HDC현대산업개발  294870
# 4         KG케미칼  001390
# ...         ...     ...
# 2564     카이바이오텍  446600
# 2565     코스텍시스템  169670
# 2566       타임기술  318660
# 2567   플럼라인생명과학  222670
# 2568   한국미라클피플사  331660
#
# [2569 rows x 2 columns]

# %% [markdown]
# https://finance.naver.com/item/sise.naver?code=005930
#
# https://finance.naver.com/item/sise_day.naver?code=005930&page=2

# %% [markdown]
# #### 잘 안됨(데이터 가져오기)

# %%
# LG화학의 일별 시세 url 가져오기
company='LG화학'
# company='LG%ED%99%94%ED%95%99'
code = stock_code[stock_code.company==company].code.values[0].strip() ## strip() : 공백제거
page = 1

url = 'https://finance.naver.com/item/sise.naver?code={code}'.format(code=code)
url = '{url}&page={page}'.format(url=url, page=page)
print(url)

# df = pd.read_html(url, header=0, encoding='euc-kr')[0]
for i in range(12):
  df = pd.read_html(url, header=0, encoding='euc-kr')[i]
  print('-------------------', i)
  print(df)

# df = pd.read_html('https://mizykk.tistory.com/39', header=0, encoding='utf-8')[2]
# encoding='utf-8' # 깨짐
# df = pd.read_html(url, header=0, encoding='euc-kr')
# df.head()
# df
# Out:
# https://finance.naver.com/item/sise.naver?code=051910&page=1
# ------------------- 0
#   전일  601,000  601,000 고가  609,000609,000  (상한가  781,000781,000  )  \
# 0   시가  603,000603,000        저가  580,000580,000  (하한가  421,000  )
#
#         거래량  189,318  189,318
# 0  거래대금  111,223  111,223  백만
# ------------------- 1
#          현재가     581,000    매도호가  581,000.1
# 0       전일대비  하락  20,000    매수호가     580000
# 1     등락률(%)      -3.33%     전일가     601000
# 2        거래량      189318      시가     603000
# 3   거래대금(백만)      111223      고가     609000
# 4        액면가      5,000원      저가     580000
# 5        NaN         NaN     NaN        NaN
# 6        상한가      781000    전일상한     781000
# 7        하한가      421000    전일하한     421000
# 8        PER       20.44     EPS      28418
# 9     52주 최고      774000  52주 최저     437000
# 10      시가총액   410,142억원   상장주식수   70592343
# 11     외국인현재    34,012천주     자본금  352,961백만
# ------------------- 2
#       매도잔량      매도호가  Unnamed: 2      매수호가    매수잔량
# ...

# %% [markdown]
# https://plotly.com/python/

# %% [markdown]
# ### PLOTLY
#
# Plotly 한번에 끝내기 - 모던한 인터랙티브 시각화 라이브러리
#
# https://www.youtube.com/watch?v=i-xbj0owgEE

# %%
import plotly.graph_objects as go

import pandas as pd
from datetime import datetime

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/finance-charts-apple.csv')

fig = go.Figure(data=[go.Candlestick(x=df['Date'],
                open=df['AAPL.Open'],
                high=df['AAPL.High'],
                low=df['AAPL.Low'],
                close=df['AAPL.Close'])])

fig.show()
df
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 14-1. [데이터 시각화] plotly 라이브러리 기초
# https://www.youtube.com/watch?v=vye_PDzAp9w

# %% [markdown]
# ### 크롤링(네이버 주식)
#
# 네이버 증권 주식 금융 데이터 크롤링 하는법 간단정리!! (1편 실시간 주가 정보)
#
# https://www.youtube.com/watch?v=QlgQ_CCCWXM

# %% [markdown]
# [데이터 시각화 Data Visualization](https://www.youtube.com/watch?v=LjWmZkW1fy0&list=PL7ZVZgsnLwEGR11m7oLOSa0pBWCc3TMaL) < 너무 어려움
#
# #### Matplotlib 한번에 끝내기 - 데이터 과학 시각화 라이브러리
#
# https://www.youtube.com/watch?v=5DfACSYgP0U < 너무 어려움(이수안)

# %% [markdown]
# ### [파이썬을 활용한 빅데이터 처리 및 시각화 (pandas, matplotlib, folium)](https://www.youtube.com/playlist?list=PLXDcZE7KzqCueLkolw30a8lKqnFFG045f)
#
#
# 9-1. [데이터 시각화] matplotlib 라이브러리 이해하기 [링크 텍스트](https://www.youtube.com/watch?v=0mWuetBETZw)
#
# [이것이 데이터 분석이다 with 파이썬_03] Numpy, Matplotlib 사용법
#
# https://www.youtube.com/watch?v=nFIAC_tv39g
#
# Matplotlib Tutorial (Part 1): Creating and Customizing Our First Plots [링크 텍스트](https://www.youtube.com/watch?v=UO98lJQ3QGI&list=PL-osiE80TeTvipOqomVEeZ1HRrcEvtZB_)
#
# Matplotlib Tutorial - 파이썬으로 데이터 시각화하기
# https://wikidocs.net/book/5011
#
# [혼란한 Matplotlib에서 질서 찾기, 이제현 - PyCon Korea 2022](https://www.youtube.com/watch?v=ZTRKojTLE8M)
#
# [ 요약강좌: [Summary 시리즈 2] [30분 Visualization 요약](https://www.youtube.com/watch?v=bOaPzbBjgl8) ]

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f7c4c83e-55b4-492c-b61d-20a87a3a6abb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f7c4c83e-55b4-492c-b61d-20a87a3a6abb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install PyOpenSSL
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 KB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 43.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# #### [구글 드라이브 마운트](https://seong6496.tistory.com/317)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 잘 안됨 : 이것은 파이참에서 실행하는 코드임, 코랩에서 잘 안됨
# 참고 : https://www.youtube.com/watch?v=hyUw-koO2DA
# import gspread
# from oauth2client.service_account import ServiceAccountCredentials
# # /content/sample_data/gsheet-python-20230107-f8046e4785c5.json
# scopes = [
#     'https://www.googleapis.com/auth/spreadsheets',
#     'https://www.googleapis.com/auth/drive'
# ]
# creds = ServiceAccountCredentials.from_json_keyfile_name('/content/sample_data/gsheet-python-20230107-f8046e4785c5.json', scopes=scopes)

# file = gspread.authorize(creds)
# workbook = file.open('Student_info')
# sheet = workbook.sheet1
# print(sheet.range('A2:A5'))

from google.colab import auth
import gspread
from google.auth import default
#autenticating to google
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# %%
from google.colab import data_table
from vega_datasets import data
data_table.enable_dataframe_formatter()

import pandas as pd


#defining my worksheet
worksheet = gc.open('excel-study_file').sheet1
# worksheet = gc.open('excel-study_file').fetch_sheet_metadata
# get_all_values gives a list of rows
rows = worksheet.get_all_values()
#Convert to a DataFrame
df = pd.DataFrame(rows)

#creating columns name
df.columns = df.iloc[0]
df = df.iloc[1:]
df
# Out:
# 0                          검색                                    833개  \
# 1    2020. 06. 19 오전 09:10:10                       ㄱ  01. FOR문.종합.정리
# 2    2020. 09. 01 오전 10:17:45                           ...vba.API.정리
# 3    2020. 08. 03 오후 01:38:41                               ..데이타.베이스
# 4    2020. 08. 05 오전 11:43:51                                 ..링크.쉬트
# 5    2020. 06. 19 오전 09:15:59                    .0001.vba.ㄱ0001.레퍼런스
# ..                        ...                                     ...
# 829  2022. 12. 26 오전 10:42:18                       vba.range.cell.정리
# 830  2020. 07. 25 오전 10:17:20                       vba.SHELL.외부 프로그램
# 831  2022. 08. 13 오전 11:42:15                                vba.word
# 832  2020. 09. 01 오전 06:32:11  vba.WORKSHEET.CALCULATE METHOD (EXCEL)
# 833  2020. 07. 21 오전 09:40:22                                     VBS
#
# 0                                         제목-프로그래밍 공부  \
# 1                                    FOR - 앞으로 이곳에 정리
# ...

# %%
from google.colab import data_table
data_table.DataTable(df, include_index=False, num_rows_per_page=50)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>검색</th>
#       <th>833개</th>
#       <th>제목-프로그래밍 공부</th>
#       <th>과거DB</th>
#       <th>소스</th>
#       <th>함수</th>
#       <th>문제집</th>
#       <th>링크검색</th>
#       <th>Excell.Object.Model</th>
#       <th>Uno</th>
#       <th>니꾸</th>
#       <th>엑셀러</th>
#       <th>Office VBA Reference</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2020. 06. 19 오전 09:10:10</td>
#       <td>ㄱ  01. FOR문.종합.정리</td>
#       <td>FOR - 앞으로 이곳에 정리</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
# ...

# %%
from google.colab import data_table
data_table.disable_dataframe_formatter()
df
# Out:
# 0                          검색                                    833개  \
# 1    2020. 06. 19 오전 09:10:10                       ㄱ  01. FOR문.종합.정리
# 2    2020. 09. 01 오전 10:17:45                           ...vba.API.정리
# 3    2020. 08. 03 오후 01:38:41                               ..데이타.베이스
# 4    2020. 08. 05 오전 11:43:51                                 ..링크.쉬트
# 5    2020. 06. 19 오전 09:15:59                    .0001.vba.ㄱ0001.레퍼런스
# ..                        ...                                     ...
# 829  2022. 12. 26 오전 10:42:18                       vba.range.cell.정리
# 830  2020. 07. 25 오전 10:17:20                       vba.SHELL.외부 프로그램
# 831  2022. 08. 13 오전 11:42:15                                vba.word
# 832  2020. 09. 01 오전 06:32:11  vba.WORKSHEET.CALCULATE METHOD (EXCEL)
# 833  2020. 07. 21 오전 09:40:22                                     VBS
#
# 0                                         제목-프로그래밍 공부  \
# 1                                    FOR - 앞으로 이곳에 정리
# ...

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

sh = gc.create('A new spreadsheet')

# Open our new sheet and add some data.
worksheet = gc.open('A new spreadsheet').sheet1

cell_list = worksheet.range('A1:C2')

import random
for cell in cell_list:
  cell.value = random.randint(1, 10)

worksheet.update_cells(cell_list)
# Go to https://sheets.google.com to see your new spreadsheet.
# Out:
# {'spreadsheetId': '1NkbC9IEtKvri7EGG167NOzzxmKetF5Cn5ih0MYNG668',
#  'updatedRange': "'시트1'!A1:C2",
#  'updatedRows': 2,
#  'updatedColumns': 3,
#  'updatedCells': 6}

# %%
# read
df1 = gc.open_by_url('https://docs.google.com/spreadsheets/d/1RnIw08TcKivKiyUQ0uqzSkLVY1_DBT3G_nDzCNxUm78/edit#gid=0')
# worksheet = gc.open('A new spreadsheet').sheet1
cell_list = df1.get_worksheet(2).range('A2:C4')
lst1 = []
for cell in cell_list:
  lst1.append(cell.value)

import numpy as np
df2 = np.reshape(lst1,(3,3))
df3 = pd.DataFrame(df2, columns=['일시', '구분', '제목'])
df3
# Out:
#                          일시                   구분                제목
# 0  2020. 06. 19 오전 09:10:10    ㄱ  01. FOR문.종합.정리  FOR - 앞으로 이곳에 정리
# 1  2020. 09. 01 오전 10:17:45        ...vba.API.정리        VBA.API.정리
# 2  2020. 08. 03 오후 01:38:41            ..데이타.베이스          엑셀.DB.정리
